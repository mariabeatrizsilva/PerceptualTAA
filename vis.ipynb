# %%
import pandas as pd

# Set display options for nice formatting
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', '{:.2f}'.format)

# Load and display summary table
summary_df = pd.read_csv('summary_table.csv')
print("\n" + "="*80)
print("SUMMARY TABLE - Min/Max/Avg Scores by Video")
print("="*80)
display(summary_df)

# Load and display optimal parameters
optimal_df = pd.read_csv('optimal_parameters.csv')
print("\n" + "="*80)
print("OPTIMAL PARAMETER VALUES")
print("="*80)
display(optimal_df)
# Out:
# ...
# SUMMARY TABLE - Min/Max/Avg Scores by Video
# ...
#                      Video  min_score  max_score  score_range  \
# 0                abandoned      95.59      97.18         1.59
# 1           abandoned-demo      97.04      97.86         0.81
# 2        abandoned-flipped      92.92      94.65         1.73
# 3                 cubetest      96.85      97.79         0.94
# 4    fantasticvillage-open      67.81      98.60        30.79
# 5             lightfoliage      91.09      92.66         1.57
# 6       lightfoliage-close      74.23      83.84         9.61
# 7                  oldmine      87.20      93.93         6.74
# 8            oldmine-close      96.79      98.86         2.07
# 9             oldmine-warm      73.63      96.15        22.52
# 10              quarry-all      82.06      90.32         8.26
# 11        quarry-rocksonly      94.34      96.35         2.01
# 12             resto-close      96.87      98.05         1.18
# ...
